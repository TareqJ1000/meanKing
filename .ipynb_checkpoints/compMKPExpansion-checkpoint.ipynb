# %%
# This code produces the experimental translation for our MKP setups

import numpy as np
import sympy as sp
from vaaGen import mkpGEN,twoKets
import copy

# Initialize symbols. We consider everything up to the 5-dimensional translation here

# Input modes 

a_0 = sp.Symbol('a_0')
a_1 = sp.Symbol('a_1')
a_2 = sp.Symbol('a_2')
a_3 = sp.Symbol('a_3')
a_4 = sp.Symbol('a_4')

b_0 = sp.Symbol('b_0')
b_1 = sp.Symbol('b_1')
b_2 = sp.Symbol('b_2')
b_3 = sp.Symbol('b_3')
b_4 = sp.Symbol('b_4')

#Detector modes
c_0 = sp.Symbol('c_0')
d_0 = sp.Symbol('d_0')
e_0 = sp.Symbol('e_0')
f_0 = sp.Symbol('f_0')
g_0 = sp.Symbol('g_0')
h_0 = sp.Symbol('h_0')
i_0 = sp.Symbol('i_0')
j_0 = sp.Symbol('j_0')
k_0 = sp.Symbol('k_0')
l_0 = sp.Symbol('l_0')

# %%
# Returns the experimental translation for our graphical solution in 2D

def expSetup2D():
    # The maximum number of possible phase shifters in our setup 
    phase_a0c = sp.Symbol('p1')
    phase_a0d = sp.Symbol('p2')
    phase_b0c = sp.Symbol('p3')
    phase_b0d = sp.Symbol('p4')
    phase_a1c = sp.Symbol('p5')
    phase_a1d = sp.Symbol('p6')
    phase_b1c = sp.Symbol('p7')
    phase_b1d = sp.Symbol('p8')
    phase_d1 = sp.Symbol('p9')
    phase_d2 = sp.Symbol('p10')
    phase_d3 = sp.Symbol('p11')
    phase_d4 = sp.Symbol('p12')
    # This is the newest graphical solution (2D)
    a_0 = c_0*phase_a0c - d_0*phase_a0d - f_0*phase_d1
    b_0 = d_0*phase_b0d - c_0*phase_b0c - 1j*f_0*phase_d2

    a_1 = 1j*(e_0*phase_a1c-f_0*phase_a1d  - d_0*phase_d3)
    b_1 = 1j*(f_0*phase_b1d-e_0*phase_b1c -1j*d_0*phase_d4)
    
    
    inputModesA = [a_0,a_1]
    inputModesB = [b_0,b_1]
    
    return inputModesA, inputModesB

# Returns the experimental translation for our graphical solution in 3D

def expSetup3D():
    # All possible phase shifters in the setup
    ####
    phase_a0c = sp.Symbol('p1')
    phase_a0d = sp.Symbol('p2')
    phase_b0c = sp.Symbol('p3')
    phase_b0d = sp.Symbol('p4')
    ####
    phase_a1e = sp.Symbol('p5')
    phase_a1f = sp.Symbol('p6')
    phase_b1e = sp.Symbol('p7')
    phase_b1f = sp.Symbol('p8')
    ####
    phase_a2g = sp.Symbol('p9')
    phase_a2h = sp.Symbol('p10')
    phase_b2g = sp.Symbol('p11')
    phase_b2h = sp.Symbol('p12')
    ####
    phase_a0e = sp.Symbol('p13')
    phase_a0g = sp.Symbol('p14')
    phase_b0e = sp.Symbol('p15')
    phase_b0g = sp.Symbol('p16')
    ####
    phase_a1d = sp.Symbol('p17')
    phase_a1h = sp.Symbol('p18')
    phase_b1d = sp.Symbol('p19')
    phase_b1h = sp.Symbol('p20')
    ####
    phase_a2c = sp.Symbol('p21')
    phase_a2f = sp.Symbol('p22')
    phase_b2c = sp.Symbol('p23')
    phase_b2f = sp.Symbol('p24')
    ####
    
    # Transformations on each input optical mode when it is sent to the setup
    
    a_0 = c_0*phase_a0c - d_0*phase_a0d - e_0*phase_a0e -1j*g_0*phase_a0g
    b_0 = d_0*phase_b0d - c_0*phase_b0c -1j*e_0*phase_b0e - g_0*phase_b0g

    a_1 = 1j*(e_0*phase_a1e - f_0*phase_a1f - d_0*phase_a1d - 1j*h_0*phase_a1h)
    b_1 = 1j*(f_0*phase_b1f-e_0*phase_b1e -1j*d_0*phase_b1d - h_0*phase_b1h)
    
    a_2 = 1j*(g_0*phase_a2g-h_0*phase_a2h-c_0*phase_a2c-1j*f_0*phase_a2f)
    b_2 = 1j*(h_0*phase_b2h-g_0*phase_b2g-1j*c_0*phase_b2c-f_0*phase_b2f)
    
    inputModesA = [a_0,a_1,a_2]
    inputModesB = [b_0,b_1,b_2]
    
    return inputModesA, inputModesB

def expSetup5D(): 
    # All possible phase shifters in the setup ... 48 in all! 
    phases = []
    for ii in range(60):
        phases.append(sp.Symbol(f"p{ii+1}"))
        
    a_0 = phases[0]*c_0 - phases[1]*d_0 -1j*phases[2]*f_0 -phases[3]*g_0 -1j*phases[4]*j_0 - phases[5]*k_0
    b_0 = phases[6]*d_0 - phases[7]*c_0 - phases[8]*f_0 -1j*phases[9]*g_0 - phases[10]*j_0 - 1j*phases[11]*k_0
    
    a_1 =  phases[12]*e_0 - phases[13]*f_0 - phases[14]*c_0 - phases[15]*g_0 -1j*phases[16]*j_0 -1j*phases[17]*l_0
    b_1 = phases[18]*f_0 - phases[19]*e_0 -1j*phases[20]*c_0 - 1j*phases[21]*g_0 - phases[22]*j_0 - phases[23]*l_0
    
    a_2 = phases[24]*g_0 - phases[25]*h_0 - phases[26]*d_0 - phases[27]*f_0 - 1j*phases[28]*k_0 - 1j*phases[29]*i_0
    b_2 = phases[30]*h_0 - phases[31]*g_0 - 1j*phases[32]*d_0 - 1j*phases[33]*f_0 - phases[34]*k_0 - phases[35]*i_0
    
    a_3 =  phases[36]*i_0 - phases[37]*j_0 - phases[38]*c_0 - phases[39]*e_0 -1j*phases[40]*l_0 - 1j*phases[41]*h_0
    b_3 =  phases[42]*j_0 - phases[43]*i_0 - 1j*phases[44]*c_0 - 1j*phases[45]*e_0 - phases[46]*l_0 - phases[47]*h_0
    
    a_4 =  phases[48]*k_0 - phases[49]*l_0 - 1j*phases[50]*d_0 - 1j*phases[51]*h_0 - phases[52]*i_0 - phases[53]*e_0
    b_4 =  phases[54]*l_0 - phases[55]*k_0 - phases[56]*d_0 -phases[57]*h_0 -1j*phases[58]*i_0 - 1j*phases[59]*e_0
    
    inputModesA = [a_0,a_1,a_2,a_3,a_4]
    inputModesB = [b_0,b_1,b_2,b_3,b_4]
    
    return inputModesA, inputModesB

# %%
# Computes the path mode expansion for each VAA state. 

def computeExpansion2D(mkpMode,detectorSet,singleDetect):
    inputModesA, inputModesB = expSetup2D()
    a_0,a_1 = inputModesA
    b_0,b_1 = inputModesB
    
    #a_0,b_0,a_1,b_1 = expSetup2D()
    # Define VAA states
    # Phases that we apply onto the higher order input path modes. 
    # These correspond to the phases observed by the first VAA state in 2D. 

    b = (np.sqrt(2)/2)*np.exp(-1j*np.pi/4)
    c = (np.sqrt(2)/2)*np.exp(+1j*np.pi/4)

    # VAA states (unnormalized)
    PHI_0 = a_0*b_0 + b*a_0*b_1 + c*a_1*b_0
    PHI_1 = a_0*b_0 - b*a_0*b_1 - c*a_1*b_0
    PHI_2 = a_1*b_1 + c*a_0*b_1 + b*a_1*b_0
    PHI_3 = a_1*b_1 - c*a_0*b_1 - b*a_1*b_0

    # Eigenstates in 2D
    # the set of measurement results by the king.
    
    hH = a_0*b_0
    vV = a_1*b_1
    aA = (a_0*b_0 + a_1*b_0 + a_0*b_1 + a_1*b_1) 
    dD = (a_0*b_0 - a_1*b_0 - a_0*b_1 + a_1*b_1)
    lL = (a_0*b_0 -1j*a_0*b_1 + 1j*a_1*b_0 + a_1*b_1)
    rR = (a_0*b_0 + 1j*a_0*b_1- 1j*a_1*b_0 + a_1*b_1)

    if(mkpMode):
        MEAN_KING = [hH,vV,lL,rR,aA,dD]
    else:
        MEAN_KING = [PHI_0,PHI_1,PHI_2,PHI_3]

    MKP_EXPANSIONS = []
    for count,PHI in enumerate(MEAN_KING):
        phiNeo = sp.expand(PHI)
        phiTotal = sp.expand(phiNeo)
        if(singleDetect == False):
            for detect in detectorSet:
                phiTotal = phiTotal.subs(detect**2, 0)
        MKP_EXPANSIONS.append(phiTotal)
    return MKP_EXPANSIONS

# Computes expansions for high-DIM VAA states

def computeExpansionHD(DIM, mkpMode, detectorSet, singleDetect):
    print(DIM)
    if(DIM==3):
        inputModesA, inputModesB = expSetup3D()
    else if(DIM==5):
            inputModesA, inputModesB = expSetup5D()
    else:
        raise Exception("Invaild dimension/no experimental setup avaliable for that dimension yet")
    if (mkpMode):
        kingStates = twoKets(DIM,False)
        MEAN_KING = [item for sublist in kingStates for item in sublist]
        print(MEAN_KING)
    else:
        MEAN_KING = mkpGEN(DIM,False)
    MKP_EXPANSIONS = []
    for count,PHI in enumerate(MEAN_KING):
        phiTotal = sp.expand(PHI)
        # We choose to neglect any terms that do not result in a two-detector click patt
        # Substitute unitary-mode transformations into main expression
        for ii in range(DIM):
            phiTotal = phiTotal.subs(f'a_{ii}',inputModesA[ii])
            phiTotal = phiTotal.subs(f'b_{ii}', inputModesB[ii])
        phiTotal = sp.expand(phiTotal)
        if(singleDetect == False):
            for detect in detectorSet:
                phiTotal=phiTotal.subs(detect**2,0)
        MKP_EXPANSIONS.append(sp.expand(phiTotal))
        print(f'{count}')
        
    return MKP_EXPANSIONS

# Creates a list of amplitude dictionary for sets of path mode expansions

def createVAACoeffs(DIM,detectorSet,mkpMode,singleDetect):
    if (DIM==2):
        MKP_EXPANSIONS = computeExpansion2D(mkpMode,detectorSet, singleDetect)
    else:
        MKP_EXPANSIONS = computeExpansionHD(DIM,mkpMode, detectorSet, singleDetect)
    coeffs = []
    for count,expand in enumerate(MKP_EXPANSIONS):
        coeff = extractCoefficients(expand,detectorSet, singleDetect)
        coeffs.append(coeff)
    return coeffs

# Creates a dictionary that documents the amplitude of two-detector click patterns for a given path mode expansion
# expansion -- sympy.Symbols? - path mode expansion for each VAA mode

def extractCoefficients(expansion,detectorSet,singleDetect):
    alreadyCheck = []
    coefficents = {}
    for alpha in detectorSet:
        for beta in detectorSet:
            if (alpha != beta and beta not in alreadyCheck):
                coefficents[alpha*beta] = sp.nsimplify(expansion.coeff(alpha*beta), tolerance=1e-10, rational=True)
        alreadyCheck.append(alpha)
    if(singleDetect):
        for alpha in detectorSet:
            coefficents[alpha*alpha] = sp.nsimplify(expansion.coeff(alpha*alpha), tolerance=1e-10, rational=True)
    return coefficents
# Out:
#   File "C:\Users\freem\AppData\Local\Temp/ipykernel_17576/2487505036.py", line 53
#     else if(DIM==5):
#          ^
# SyntaxError: invalid syntax

# %%
# Detector sets for different DIM cases
detectorSet2D = [c_0,d_0,e_0,f_0]
detectorSet3D = [c_0,d_0,e_0,f_0,g_0,h_0]
detectorSet5D = [c_0,d_0,e_0,f_0,g_0,h_0,i_0,j_0,k_0,l_0]

# %%
# Storing the information (here we consider 3D expansion)
kk = createVAACoeffs(5, detectorSet3D, False, True)

#Container of all the VAA states. Each element is a string with the coefficient tranlation
AllTheThingsYouSaid=[];

# The number of VAA states
NumberOfElements=len(kk)

# Generates the translation from 'p_i' to the 'p[i-1]'
old=[('p'+str(ii),'p['+str(ii-1)+']') for ii in np.arange(60,0,-1)]

for ii in np.arange(0,NumberOfElements):
    # Retrieves the keys in the dictionary 
    Keys=kk[ii].keys()
    # Initialize the text for each entry
    text1=''
    for key in Keys:
        # Replaces I with the complex number 1j in Python
        thing=str(kk[ii][key]).replace('I','1j')
        for pair in old:
            #Performs the replacement of the pairs 
            thing=thing.replace(pair[0],pair[1])
        # Attaches all the coefficients to form the equations
        text1=text1+str(key).replace('*','')+'='+thing+'\n\t'
    
    #Adds it to the Mother List 
    AllTheThingsYouSaid.append(text1)
# Out:
# 5
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17576/880807053.py in <module>
#       1 # Storing the information (here we consider 3D expansion)
# ----> 2 kk = createVAACoeffs(5, detectorSet3D, False, True)
#       3
#       4 #Container of all the VAA states. Each element is a string with the coefficient tranlation
#       5 AllTheThingsYouSaid=[];
#
# ~\AppData\Local\Temp/ipykernel_17576/3337063212.py in createVAACoeffs(DIM, detectorSet, mkpMode, singleDetect)
#      84         MKP_EXPANSIONS = computeExpansion2D(mkpMode,detectorSet, singleDetect)
#      85     else:
# ---> 86         MKP_EXPANSIONS = computeExpansionHD(DIM,mkpMode, detectorSet, singleDetect)
#      87     coeffs = []
#      88     for count,expand in enumerate(MKP_EXPANSIONS):
#
# ~\AppData\Local\Temp/ipykernel_17576/3337063212.py in computeExpansionHD(DIM, mkpMode, detectorSet, singleDetect)
#      73             for detect in detectorSet:
#      74                 phiTotal=phiTotal.subs(detect**2,0)
# ---> 75         MKP_EXPANSIONS.append(sp.expand(phiTotal))
#      76         print(f'{count}')
#      77
#
# ~\anaconda3\lib\site-packages\sympy\core\function.py in expand(e, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    2823     hints['multinomial'] = multinomial
#    2824     hints['basic'] = basic
# -> 2825     return sympify(e).expand(deep=deep, modulus=modulus, **hints)
#    2826
#    2827 # This is a special application of two hints
#
# ~\anaconda3\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError as e:
#      74                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# ~\anaconda3\lib\site-packages\sympy\core\expr.py in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    3620             if use_hint:
#    3621                 hint = '_eval_expand_' + hint
# -> 3622                 expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    3623
#    3624         while True:
#
# ~\anaconda3\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    3553             sargs = []
#    3554             for arg in expr.args:
# -> 3555                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3556                 hit |= arghit
#    3557                 sargs.append(arg)
#
# ~\anaconda3\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    3561
#    3562         if hasattr(expr, hint):
# -> 3563             newexpr = getattr(expr, hint)(**hints)
#    3564             if newexpr != expr:
#    3565                 return (newexpr, True)
#
# ~\anaconda3\lib\site-packages\sympy\core\mul.py in _eval_expand_mul(self, **hints)
#     934         # to 1/x*1/(x + 1)
#     935         expr = self
# --> 936         n, d = fraction(expr)
#     937         if d.is_Mul:
#     938             n, d = [i._eval_expand_mul(**hints) if i.is_Mul else i
#
# ~\anaconda3\lib\site-packages\sympy\simplify\radsimp.py in fraction(expr, exact)
#    1111         else:
#    1112             numer.append(term)
# -> 1113     return Mul(*numer, evaluate=not exact), Mul(*denom, evaluate=not exact)
#    1114
#    1115
#
# ~\anaconda3\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError as e:
#      74                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# ~\anaconda3\lib\site-packages\sympy\core\operations.py in __new__(cls, evaluate, _sympify, *args)
#      86         is_commutative = not nc_part
#      87         obj = cls._from_args(c_part + nc_part, is_commutative)
# ---> 88         obj = cls._exec_constructor_postprocessors(obj)
#      89
#      90         if order_symbols is not None:
#
# ~\anaconda3\lib\site-packages\sympy\core\basic.py in _exec_constructor_postprocessors(cls, obj)
#    1838
#    1839         clsname = obj.__class__.__name__
# -> 1840         postprocessors = defaultdict(list)
#    1841         for i in obj.args:
#    1842             try:
#
# KeyboardInterrupt:

# %%
AllTheThingsYouSaid[0]
#viggo = sp.nsimplify(test, tolerance=1e-10, rational=False)
# Out:
# 'c_0d_0=324625355*p[0]*p[6]/725884361 - 324625355*p[14]*p[6]/725884361 + 324625355*1j*p[1]*p[20]/725884361 + 324625355*p[1]*p[7]/725884361\n\tc_0e_0=-324625355*p[0]*p[19]/725884361 - 324625355*p[12]*p[7]/725884361\n\tc_0f_0=324625355*p[0]*p[18]/725884361 - 324625355*p[0]*p[8]/725884361 + 324625355*p[13]*p[7]/725884361 + 324625355*p[14]*p[8]/725884361 - 324625355*p[20]*p[2]/725884361 + 324625355*1j*p[2]*p[7]/725884361\n\tc_0g_0=-324625355*1j*p[0]*p[9]/725884361 - 324625355*1j*p[0]*p[21]/725884361 + 324625355*1j*p[9]*p[14]/725884361 + 324625355*p[15]*p[7]/725884361 + 324625355*1j*p[20]*p[3]/725884361 + 324625355*p[3]*p[7]/725884361\n\tc_0h_0=0\n\tc_0i_0=0\n\tc_0j_0=-324625355*p[0]*p[10]/725884361 - 324625355*p[0]*p[22]/725884361 + 324625355*p[10]*p[14]/725884361 + 324625355*1j*p[16]*p[7]/725884361 - 324625355*p[20]*p[4]/725884361 + 324625355*1j*p[4]*p[7]/725884361\n\tc_0k_0=-324625355*1j*p[0]*p[11]/725884361 + 324625355*1j*p[11]*p[14]/725884361 + 324625355*1j*p[20]*p[5]/725884361 + 324625355*p[5]*p[7]/725884361\n\tc_0l_0=-324625355*p[0]*p[23]/725884361 + 324625355*1j*p[17]*p[7]/725884361\n\td_0e_0=324625355*p[12]*p[6]/725884361 + 324625355*p[1]*p[19]/725884361 + 4111283717*1j*p[26]*p[59]/9193109866 + 4111283717*1j*p[32]*p[53]/9193109866\n\td_0f_0=-324625355*p[13]*p[6]/725884361 - 324625355*p[18]*p[1]/725884361 + 324625355*p[1]*p[8]/725884361 + 4111283717*p[27]*p[56]/9193109866 - 324625355*1j*p[2]*p[6]/725884361 - 4111283717*p[33]*p[50]/9193109866\n\td_0g_0=324625355*1j*p[9]*p[1]/725884361 - 324625355*p[15]*p[6]/725884361 + 324625355*1j*p[1]*p[21]/725884361 - 4111283717*p[24]*p[56]/9193109866 + 4111283717*1j*p[31]*p[50]/9193109866 - 324625355*p[3]*p[6]/725884361\n\td_0h_0=4111283717*p[25]*p[56]/9193109866 + 4111283717*p[26]*p[57]/9193109866 - 4111283717*1j*p[30]*p[50]/9193109866 - 4111283717*p[32]*p[51]/9193109866\n\td_0i_0=4111283717*1j*p[26]*p[58]/9193109866 + 4111283717*1j*p[29]*p[56]/9193109866 + 4111283717*1j*p[32]*p[52]/9193109866 + 4111283717*1j*p[35]*p[50]/9193109866\n\td_0j_0=324625355*p[10]*p[1]/725884361 - 324625355*1j*p[16]*p[6]/725884361 + 324625355*p[1]*p[22]/725884361 - 324625355*1j*p[4]*p[6]/725884361\n\td_0k_0=324625355*1j*p[11]*p[1]/725884361 + 4111283717*p[26]*p[55]/9193109866 + 4111283717*1j*p[28]*p[56]/9193109866 - 4111283717*1j*p[32]*p[48]/9193109866 + 4111283717*1j*p[34]*p[50]/9193109866 - 324625355*p[5]*p[6]/725884361\n\td_0l_0=-324625355*1j*p[17]*p[6]/725884361 + 324625355*p[1]*p[23]/725884361 - 4111283717*p[26]*p[54]/9193109866 + 4111283717*1j*p[32]*p[49]/9193109866\n\te_0f_0=-324625355*p[12]*p[8]/725884361 + 324625355*1j*p[19]*p[2]/725884361 + 4111283717*1j*p[27]*p[59]/9193109866 + 4111283717*1j*p[33]*p[53]/9193109866\n\te_0g_0=-324625355*1j*p[9]*p[12]/725884361 + 324625355*p[19]*p[3]/725884361 - 4111283717*1j*p[24]*p[59]/9193109866 + 4111283717*p[31]*p[53]/9193109866\n\te_0h_0=4111283717*1j*p[25]*p[59]/9193109866 - 4111283717*p[30]*p[53]/9193109866\n\te_0i_0=-4111283717*p[29]*p[59]/9193109866 + 4111283717*p[35]*p[53]/9193109866\n\te_0j_0=-324625355*p[10]*p[12]/725884361 + 324625355*1j*p[19]*p[4]/725884361\n\te_0k_0=-324625355*1j*p[11]*p[12]/725884361 + 324625355*p[19]*p[5]/725884361 - 4111283717*p[28]*p[59]/9193109866 + 4111283717*p[34]*p[53]/9193109866\n\te_0l_0=0\n\tf_0g_0=324625355*1j*p[9]*p[13]/725884361 - 324625355*p[9]*p[2]/725884361 + 324625355*p[15]*p[8]/725884361 - 324625355*p[18]*p[3]/725884361 - 324625355*p[21]*p[2]/725884361 + 324625355*p[3]*p[8]/725884361\n\tf_0h_0=4111283717*p[27]*p[57]/9193109866 - 4111283717*p[33]*p[51]/9193109866\n\tf_0i_0=4111283717*1j*p[27]*p[58]/9193109866 + 4111283717*1j*p[33]*p[52]/9193109866\n\tf_0j_0=324625355*p[10]*p[13]/725884361 + 324625355*1j*p[10]*p[2]/725884361 + 324625355*1j*p[16]*p[8]/725884361 - 324625355*1j*p[18]*p[4]/725884361 + 324625355*1j*p[22]*p[2]/725884361 + 324625355*1j*p[4]*p[8]/725884361\n\tf_0k_0=324625355*1j*p[11]*p[13]/725884361 - 324625355*p[11]*p[2]/725884361 - 324625355*p[18]*p[5]/725884361 + 4111283717*p[27]*p[55]/9193109866 - 41112837 ...

# %%
# Function that writes multiple function files in a single txt file   

def WriteCode2(name, funName):
    #Creates the output vector 
    ret=''
    Keys=list(kk[0].keys())
    for ii in np.arange(0,len(Keys),1):
        if ii<(len(Keys)-1):
            ret=ret+str(Keys[ii]).replace('*','')+','
        else:
            ret=ret+str(Keys[ii]).replace('*','')
    with open(name+'.txt','w') as f:
        for Number in range(len(AllTheThingsYouSaid)):
            funNameN = funName+f"_{Number}"
            f.write('def '+funNameN +'(p): \n\t'+AllTheThingsYouSaid[Number]+'\n\tout=('+ret+')\n\treturn(out)\n\n')

# %%
WriteCode2('superV_5D_SD_MKP','superVAA')

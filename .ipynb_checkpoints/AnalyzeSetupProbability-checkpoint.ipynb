# %%
import numpy as np
import sympy as sp
from compSuccessProb import computeProb, createCompleteSet, MostProbClicks, calcCoeffsNeo, createSingleDetect, calcDetectorProbs
from mkpSuccessProb import compBasis, computeMKPSU 

import seaborn as sns
import matplotlib.cm as cm 
import matplotlib.pyplot as plt
import math 

#Detector modes
c_0 = sp.Symbol('c_0')
d_0 = sp.Symbol('d_0')
e_0 = sp.Symbol('e_0')
f_0 = sp.Symbol('f_0')
g_0 = sp.Symbol('g_0')
h_0 = sp.Symbol('h_0')
i_0 = sp.Symbol('i_0')
j_0 = sp.Symbol('j_0')
k_0 = sp.Symbol('k_0')
l_0 = sp.Symbol('l_0')

# Function which plots the detector probabilities
def plot_detector_probs(DIM, coeffList, twoClicks):
    colors = cm.rainbow(np.linspace(0, 1, DIM**2))

    # Create float list of coefficents
    keyLists = []

    for detect in twoClicks:
        prod = f"${detect}$" 
        prod2 = prod.replace("*",'') 
        keyLists.append(prod2)

    fig, axes = plt.subplots(nrows=DIM, ncols=DIM, figsize=(12,12))

    # Make subplots

    for i, ax in enumerate(axes.flatten()):
        ax.set_title(f'$|\phi_{i}>$')  # Set a title for each subplot
        sns.barplot(x=keyLists, y=coeffList[i], ax=ax,color=colors[math.floor(i)])
        ax.tick_params(axis='x', rotation=45)
        ax.set_ylim([0,1])
        
        
# Prints out the most probable detector clicks in each case

def print_most_probs(bestPhases, detectorSet, DIM, vaaFun, singleDetect):
    mostProbs = MostProbClicks(bestPhases, detectorSet, DIM, vaaFun, singleDetect)
    for key, tup in zip(mostProbs.keys(), mostProbs.values()):
        print(f"Detector Pattern {key}, Most Probable VAA State {tup[0]}, Probability {tup[1]}")

# Compute success probability for VAA state in 2D 

def comp_vaa_2d():
    vaaOrtho = {}
    vaaOrtho[0] = [(0,0), (1,0), (2,0)] # (basis, eigenstate)
    vaaOrtho[1] = [(0,0), (1,1), (2,1)]
    vaaOrtho[2] = [(0,1), (1,1), (2,0)]
    vaaOrtho[3] = [(0,1), (1,0), (2,1)]
    return vaaOrtho

def comp_basis_2D(DIM,m):
    vaaOrtho = comp_vaa_2d()
    basis = []
    
    for ii in range(DIM):
        temp = []
        for count, raga in enumerate(vaaOrtho.values()):
            if(raga[m][1] == ii):
                temp.append(count)
        basis.append(temp)
        

    return basis

# %% [markdown]
# print out the numbers to compute the 2D MKP success probability

# %%
mkp_0 = comp_basis_2D(2,0)
mkp_1 = comp_basis_2D(2,1)
mkp_2 = comp_basis_2D(2,2)

# %% [markdown]
# # Calculate/Plot Detector Probabilities

# %% [markdown]
# ***2D Case:***

# %%
DIM = 2
singleDetect = False
detectorSet = [c_0, d_0, e_0, f_0]

# %% [markdown]
# **For setup featured in the figure/thesis**

# %%
bestPhases = np.load('bestPhases/MKP_2D_PaperSetupFixed.npy')

vaaFun = 'expansionFuncs/2D_MKP_PaperSetupFixed.txt'
mkpFun = 'expansionFuncs/2D_MKP_PaperSetupFixed_MKPSD.txt'

coeffsList = calcCoeffsNeo(bestPhases, vaaFun, DIM)
probLists = computeProb(bestPhases,vaaFun,DIM)

print(probLists)

detectorSets = createCompleteSet(detectorSet,singleDetect)
plot_detector_probs(DIM, probLists, detectorSets)
# Out:
# [[0.09753416507529113, 0.40153195377788925, 0.09553450417481363, 0.2879070301606642, 0.09553450417481363, 0.02195784263652843], [0.6805704028429577, 0.000550563793796826, 0.12617631629983594, 0.037525782382816404, 0.12617631629983594, 0.029000618380757306], [0.008225583306341586, 0.008225583306341586, 0.008225583306341586, 0.38321739787616543, 0.12749000153535567, 0.46461585066945416], [0.02400100350084883, 0.02400100350084883, 0.024001003500848824, 0.15924609379963697, 0.697938567454671, 0.07081232824314543]]

# %% [markdown]
#  What are the states that are most likely to trigger each detector?

# %%
mostProbs = MostProbClicks(bestPhases, detectorSet, DIM, vaaFun, singleDetect)
print_most_probs(bestPhases, detectorSet, DIM, vaaFun, singleDetect)
# Out:
# Detector Pattern c_0*d_0, Most Probable VAA State 1, Probability 0.6805704028429577
# Detector Pattern c_0*e_0, Most Probable VAA State 0, Probability 0.40153195377788925
# Detector Pattern c_0*f_0, Most Probable VAA State 1, Probability 0.12617631629983594
# Detector Pattern d_0*e_0, Most Probable VAA State 2, Probability 0.38321739787616543
# Detector Pattern d_0*f_0, Most Probable VAA State 3, Probability 0.697938567454671
# Detector Pattern e_0*f_0, Most Probable VAA State 2, Probability 0.46461585066945416

# %% [markdown]
# What are the single detector click probabilities?

# %%
singleSets = createSingleDetect(detectorSet)
# Probabilities triggered by each detector 

detector_probs = calcDetectorProbs(detectorSet, coeffsList, True)
total_loss_by_VAA = {0:[], 1:[], 2:[], 3:[]}

# Compute single detector settings -- list by probability 

for detec in singleSets:
    probs = detector_probs[detec]
    print(probs)
    total_loss_by_VAA[0].append(probs[0][1])
    total_loss_by_VAA[1].append(probs[1][1])
    total_loss_by_VAA[2].append(probs[2][1])
    total_loss_by_VAA[3].append(probs[3][1])

    
# Now sum up the lists to obtain total loss due to the single detector set 
for ii in range(4):
    print(f"VAA Set: {ii}, Total Loss due to Single Detector Clicks: {np.sum(total_loss_by_VAA[ii])}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[60], line 4
#       1 singleSets = createSingleDetect(detectorSet)
#       2 # Probabilities triggered by each detector
# ----> 4 detector_probs = calcDetectorProbs(detectorSet, coeffsList, True)
#       5 total_loss_by_VAA = {0:[], 1:[], 2:[], 3:[]}
#       7 # Compute single detector settings -- list by probability
#
# File ~\Desktop\SalvageMeanKing\compSuccessProb.py:83, in calcDetectorProbs(detectorSet, coeffs, singleDetect)
#      81     temp = []
#      82     for jj in range(len(coeffs)):
# ---> 83         temp.append((jj, np.abs(coeffs[jj][ii])**2))
#      84     detectorProbs[detector] = temp
#      85 return detectorProbs
#
# IndexError: list index out of range

# %% [markdown]
# Mean king probability

# %%
mkpCoeffLists = computeProb(bestPhases, mkpFun, DIM)

print(len(mkpCoeffLists))

computeMKPSU(mkp_0, detectorSets, mostProbs, mkpCoeffLists[0:2])
computeMKPSU(mkp_1, detectorSets, mostProbs, mkpCoeffLists[2:4])
computeMKPSU(mkp_2, detectorSets, mostProbs, mkpCoeffLists[4:6])
# Out:
# 6
# success probabilities (state-by-state): [0.7499999999999998, 1.0000000000000002]
# average success probability: 0.875
# success probabilities (state-by-state): [0.306395139034171, 0.55796768120469]
# average success probability: 0.43218141011943045
# success probabilities (state-by-state): [0.6551512835782245, 0.5685779259093727]
# average success probability: 0.6118646047437986
# 0.6118646047437986

# %% [markdown]
# **For more complicated setup that implements six detectors**

# %%
bestPhases = np.load('bestPhases/2D_MKP_ComplexPaperSetup.npy')
detectorSet = [c_0, d_0, e_0, f_0, g_0, h_0]
singleDetect = True

vaaFun = 'expansionFuncs/2D_MKP_ComplexPaperSetup.txt'
mkpFun = 'expansionFuncs/2D_MKP_ComplexPaperSetup_MKPSP.txt'

coeffsList = calcCoeffsNeo(bestPhases, vaaFun, DIM)
probLists = computeProb(bestPhases,vaaFun,DIM)

detectorSets = createCompleteSet(detectorSet,singleDetect)
plot_detector_probs(DIM, probLists, detectorSets)

# %% [markdown]
# What are the states most likely to trigger the detector

# %%
mostProbs = MostProbClicks(bestPhases, detectorSet, DIM, vaaFun, singleDetect)
print_most_probs(bestPhases, detectorSet, DIM, vaaFun, singleDetect)
# Out:
# Detector Pattern c_0*d_0, Most Probable VAA State 0, Probability 0.2521562201969238
# Detector Pattern c_0*e_0, Most Probable VAA State 1, Probability 0.006187938705946261
# Detector Pattern c_0*f_0, Most Probable VAA State 1, Probability 0.09098625351543528
# Detector Pattern c_0*g_0, Most Probable VAA State 1, Probability 0.2521562201969238
# Detector Pattern c_0*h_0, Most Probable VAA State 2, Probability 0.060124338786617444
# Detector Pattern d_0*e_0, Most Probable VAA State 2, Probability 0.07812192443813784
# Detector Pattern d_0*f_0, Most Probable VAA State 0, Probability 0.2521562201969237
# Detector Pattern d_0*g_0, Most Probable VAA State 2, Probability 0.18610504184537113
# Detector Pattern d_0*h_0, Most Probable VAA State 3, Probability 0.34702176606026086
# Detector Pattern e_0*f_0, Most Probable VAA State 1, Probability 0.006187938705946261
# Detector Pattern e_0*g_0, Most Probable VAA State 2, Probability 0.07812192443813787
# Detector Pattern e_0*h_0, Most Probable VAA State 0, Probability 0.03944372648128509
# Detector Pattern f_0*g_0, Most Probable VAA State 1, Probability 0.2521562201969238
# Detector Pattern f_0*h_0, Most Probable VAA State 2, Probability 0.060124338786617444
# Detector Pattern g_0*h_0, Most Probable VAA State 2, Probability 0.34702176606026086
# Detector Pattern c_0**2, Most Probable VAA State 1, Probability 0.02274656337885882
# Detector Pattern d_0**2, Most Probable VAA State 0, Probability 0.11989007627827616
# Detector Pattern e_0**2, Most Probable VAA State 1, Probability 0.02274656337885882
# Detector Pattern f_0**2, Most Probable VAA State 1, Probability 0.02274656337885882
# Detector Pattern g_0**2, Most Probable VAA State 1, Probability 0.1198900762782762
# Detector Pattern h_0**2, Most Probable VAA State 2, Probability 0.04652626046134278

# %% [markdown]
# Mean king probability

# %%
mkpCoeffLists = computeProb(bestPhases, mkpFun, DIM)

print(len(mkpCoeffLists))

computeMKPSU(mkp_0, detectorSets, mostProbs, mkpCoeffLists[0:2])
computeMKPSU(mkp_1, detectorSets, mostProbs, mkpCoeffLists[2:4])
computeMKPSU(mkp_2, detectorSets, mostProbs, mkpCoeffLists[4:6])
# Out:
# 6
# success probabilities (state-by-state): [0.8594317263273348, 0.36363636363636365]
# average success probability: 0.6115340449818492
# success probabilities (state-by-state): [0.4687284152039603, 0.894379580174073]
# average success probability: 0.6815539976890167
# success probabilities (state-by-state): [0.8497488520000328, 0.982376089307278]
# average success probability: 0.9160624706536554
# 0.9160624706536554

# %% [markdown]
# **3D Case**

# %%
from mkpSuccessProb import compBasis

DIM = 3
singleDetect = False
detectorSet = [c_0, d_0, e_0, f_0, g_0, h_0]

# Basis in 3D 

zeroBasis =  compBasis(3,0)
oneBasis = compBasis(3,1)
twoBasis = compBasis(3,2)
threeBasis = compBasis(3,3)

bestPhases = np.load('bestPhases/October 8th, MKP_3D_PaperSetupFixed.npy')

vaaFun = 'expansionFuncs/MKP_3D_PaperSetupFixed.txt'
mkpFun = 'expansionFuncs/MKP_3D_PaperSetupFixed_MKPSD.txt'
coeffsList = calcCoeffsNeo(bestPhases, vaaFun, DIM)
probLists = computeProb(bestPhases, vaaFun,DIM)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11660/1535007459.py in <module>
#      12 threeBasis = compBasis(3,3)
#      13
# ---> 14 bestPhases = np.load('bestPhases/MKP_3D_PaperSetupFixed.npy')
#      15
#      16 vaaFun = 'expansionFuncs/MKP_3D_PaperSetupFixed.txt'
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     405             own_fid = False
#     406         else:
# --> 407             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     408             own_fid = True
#     409
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bestPhases/MKP_3D_PaperSetupFixed.npy'

# %% [markdown]
# Plot detector probabilities

# %%
detectorSets = createCompleteSet(detectorSet,singleDetect)
plot_detector_probs(DIM, probLists, detectorSets)

# %% [markdown]
# What detectors are most likely to trigger a click?

# %%
mostProbs = MostProbClicks(bestPhases, detectorSet, DIM, vaaFun, singleDetect)
print_most_probs(bestPhases, detectorSet, DIM, vaaFun, singleDetect)
# Out:
# Detector Pattern c_0*d_0, Most Probable VAA State 2, Probability 0.6750313355659203
# Detector Pattern c_0*e_0, Most Probable VAA State 3, Probability 0.3078659432017562
# Detector Pattern c_0*f_0, Most Probable VAA State 1, Probability 0.6347214983681476
# Detector Pattern c_0*g_0, Most Probable VAA State 5, Probability 0.10284451221359649
# Detector Pattern c_0*h_0, Most Probable VAA State 8, Probability 0.19967346670863864
# Detector Pattern d_0*e_0, Most Probable VAA State 0, Probability 0.4530343375191201
# Detector Pattern d_0*f_0, Most Probable VAA State 7, Probability 0.24295159715688297
# Detector Pattern d_0*g_0, Most Probable VAA State 8, Probability 0.19967346670863864
# Detector Pattern d_0*h_0, Most Probable VAA State 4, Probability 0.1835652094240701
# Detector Pattern e_0*f_0, Most Probable VAA State 6, Probability 0.2730702630690027
# Detector Pattern e_0*g_0, Most Probable VAA State 0, Probability 0.07174230445330906
# Detector Pattern e_0*h_0, Most Probable VAA State 8, Probability 0.19967346670863864
# Detector Pattern f_0*g_0, Most Probable VAA State 8, Probability 0.19967346670863864
# Detector Pattern f_0*h_0, Most Probable VAA State 4, Probability 0.08664542017220041
# Detector Pattern g_0*h_0, Most Probable VAA State 5, Probability 0.10314346870140831

# %% [markdown]
# Mean King Probability

# %%
mkpCoeffLists = computeProb(bestPhases, mkpFun, DIM)

# Compute most probable detectors

SuProb_0 = computeMKPSU(zeroBasis, detectorSets, mostProbs, mkpCoeffLists[0:DIM])
SuProb_1 = computeMKPSU(oneBasis, detectorSets, mostProbs, mkpCoeffLists[DIM:2*DIM])
SuProb_2 = computeMKPSU(twoBasis, detectorSets, mostProbs, mkpCoeffLists[2*DIM:3*DIM])
SuProb_3 = computeMKPSU(threeBasis, detectorSets, mostProbs, mkpCoeffLists[3*DIM:4*DIM])

print(SuProb_0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11660/3620686608.py in <module>
# ----> 1 mkpCoeffLists = computeProb(bestPhases, mkpFun, DIM)
#       2
#       3 # Compute most probable detectors
#       4
#       5 SuProb_0 = computeMKPSU(zeroBasis, detectorSets, mostProbs, mkpCoeffLists[0:DIM])
#
# NameError: name 'bestPhases' is not defined

# %% [markdown]
# More Complicated 3D Setup

# %%
DIM = 3
singleDetect = True
detectorSet = [c_0, d_0, e_0, f_0, g_0, h_0, i_0, j_0]

bestPhases = np.load('bestPhases/MKP_3D_ComplexPaperSetup.npy')

vaaFun = 'expansionFuncs/MKP_3D_ComplexPaperSetup.txt'
mkpFun = 'expansionFuncs/MKP_3D_ComplexPaperSetup_MKPSP.txt'
coeffsList = calcCoeffsNeo(bestPhases, vaaFun, DIM)
probLists = computeProb(bestPhases, vaaFun,DIM)

# %% [markdown]
# Plot detector probabilities

# %%
detectorSets = createCompleteSet(detectorSet,singleDetect)
plot_detector_probs(DIM, probLists, detectorSets)

# %% [markdown]
# what detectors are most likely to trigger a click?

# %%
mostProbs = MostProbClicks(bestPhases, detectorSet, DIM, vaaFun, singleDetect)
print_most_probs(bestPhases, detectorSet, DIM, vaaFun, singleDetect)
# Out:
# Detector Pattern c_0*d_0, Most Probable VAA State 1, Probability 0.45361894878767856
# Detector Pattern c_0*e_0, Most Probable VAA State 6, Probability 0.039207788486390484
# Detector Pattern c_0*f_0, Most Probable VAA State 6, Probability 0.039207788486390484
# Detector Pattern c_0*g_0, Most Probable VAA State 5, Probability 0.11434522357901195
# Detector Pattern c_0*h_0, Most Probable VAA State 2, Probability 0.4555935578569876
# Detector Pattern c_0*i_0, Most Probable VAA State 8, Probability 0.1738920841546116
# Detector Pattern c_0*j_0, Most Probable VAA State 6, Probability 0.039227195740011676
# Detector Pattern d_0*e_0, Most Probable VAA State 4, Probability 0.10254275537372019
# Detector Pattern d_0*f_0, Most Probable VAA State 8, Probability 0.1738920841546116
# Detector Pattern d_0*g_0, Most Probable VAA State 0, Probability 0.24238324051529017
# Detector Pattern d_0*h_0, Most Probable VAA State 8, Probability 0.1739099383932759
# Detector Pattern d_0*i_0, Most Probable VAA State 4, Probability 0.10256192186039863
# Detector Pattern d_0*j_0, Most Probable VAA State 4, Probability 0.10256192186039863
# Detector Pattern e_0*f_0, Most Probable VAA State 0, Probability 0.06057053881639634
# Detector Pattern e_0*g_0, Most Probable VAA State 6, Probability 0.039207788486390484
# Detector Pattern e_0*h_0, Most Probable VAA State 4, Probability 0.10254275537372012
# Detector Pattern e_0*i_0, Most Probable VAA State 6, Probability 0.039222741306547064
# Detector Pattern e_0*j_0, Most Probable VAA State 2, Probability 0.06452050250704973
# Detector Pattern f_0*g_0, Most Probable VAA State 6, Probability 0.039207788486390484
# Detector Pattern f_0*h_0, Most Probable VAA State 8, Probability 0.1738920841546116
# Detector Pattern f_0*i_0, Most Probable VAA State 5, Probability 0.038111161491558604
# Detector Pattern f_0*j_0, Most Probable VAA State 0, Probability 0.06060052030359984
# Detector Pattern g_0*h_0, Most Probable VAA State 0, Probability 0.24238324051529017
# Detector Pattern g_0*i_0, Most Probable VAA State 8, Probability 0.1738920841546116
# Detector Pattern g_0*j_0, Most Probable VAA State 6, Probability 0.039227195740011676
# Detector Pattern h_0*i_0, Most Probable VAA State 4, Probability 0.10256192186039863
# Detector Pattern h_0*j_0, Most Probable VAA State 4, Probability 0.10256192186039863
# Detector Pattern i_0*j_0, Most Probable VAA State 6, Probability 0.039230072513378844
# Detector Pattern c_0**2, Most Probable VAA State 2, Probability 0.06540960189081871
# Detector Pattern d_0**2, Most Probable VAA State 6, Probability 0.13660123851895484
# Detector Pattern e_0**2, Most Probable VAA State 2, Probability 0.016133850308624364
# Detector Pattern f_0**2, Most Probable VAA State 5, Probability 0.028586305894752986
# Detector Pattern g_0**2, Most Probable VAA State 0, Probability 0.13630962439251723
# Detector Pattern h_0**2, Most Probable VAA State 7, Probability 0.13650726130302226
# Detector Pattern i_0**2, Most Probable VAA State 8, Probability 0.043477484598318974
# Detector Pattern j_0**2, Most Probable VAA State 2, Probability 0.01613385030862435

# %% [markdown]
# MKP Sucess Probability

# %%
mkpCoeffLists = computeProb(bestPhases, mkpFun, DIM)

# Compute most probable detectors

SuProb_0 = computeMKPSU(zeroBasis, detectorSets, mostProbs, mkpCoeffLists[0:DIM])
SuProb_1 = computeMKPSU(oneBasis, detectorSets, mostProbs, mkpCoeffLists[DIM:2*DIM])
SuProb_2 = computeMKPSU(twoBasis, detectorSets, mostProbs, mkpCoeffLists[2*DIM:3*DIM])
SuProb_3 = computeMKPSU(threeBasis, detectorSets, mostProbs, mkpCoeffLists[3*DIM:4*DIM])
# Out:
# success probabilities (state-by-state): [0.7057657208749499, 0.7142857142857141, 0.9999999999999996]
# average success probability: 0.8066838117202212
# success probabilities (state-by-state): [0.8748656196006002, 0.5690048739655094, 0.6817954494186219]
# average success probability: 0.7085553143282438
# success probabilities (state-by-state): [0.7961127686380332, 0.3925651684723443, 0.6798624612948984]
# average success probability: 0.6228467994684252
# success probabilities (state-by-state): [0.8129357702341103, 0.406804325067713, 0.5327604560954382]
# average success probability: 0.5841668504657539

# %% [markdown]
# **5D MKP**

# %%
from mkpSuccessProb import compBasis

DIM = 5
singleDetect = False
detectorSet = [c_0, d_0, e_0, f_0, g_0, h_0,i_0,j_0,k_0,l_0]

# Basis in 5D 

zeroBasis =  compBasis(5,0)
oneBasis = compBasis(5,1)
twoBasis = compBasis(5,2)
threeBasis = compBasis(5,3)
fourBasis = compBasis(5,4)
fiveBasis = compBasis(5,5)

bestPhases = np.load('bestPhases/MKP_5D_PaperSetupFixed.npy')

vaaFun = 'expansionFuncs/MKP_5D_PaperSetupFixed.txt'
mkpFun = 'expansionFuncs/MKP_5D_PaperSetupFixed_MKPSP.txt'
coeffsList = calcCoeffsNeo(bestPhases, vaaFun, DIM)
probLists = computeProb(bestPhases, vaaFun,DIM)

detectorSets = createCompleteSet(detectorSet,singleDetect)
mostProbs = MostProbClicks(bestPhases, detectorSet, DIM, vaaFun, singleDetect)
mkpCoeffLists = computeProb(bestPhases, mkpFun, DIM)

# Compute most probable detectors

SuProb_0 = computeMKPSU(zeroBasis, detectorSets, mostProbs, mkpCoeffLists[0:DIM])
SuProb_1 = computeMKPSU(oneBasis, detectorSets, mostProbs, mkpCoeffLists[DIM:2*DIM])
SuProb_2 = computeMKPSU(twoBasis, detectorSets, mostProbs, mkpCoeffLists[2*DIM:3*DIM])
SuProb_3 = computeMKPSU(threeBasis, detectorSets, mostProbs, mkpCoeffLists[3*DIM:4*DIM])
SuProb_4 = computeMKPSU(fourBasis, detectorSets, mostProbs, mkpCoeffLists[4*DIM:5*DIM])
SuProb_5 = computeMKPSU(fiveBasis, detectorSets, mostProbs, mkpCoeffLists[5*DIM:6*DIM])
# Out:
# success probabilities (state-by-state): [0.35714285714285715, 1.0000000000000002, 1.0000000000000002, 0.0, 0.6666666666666669]
# average success probability: 0.604761904761905
# success probabilities (state-by-state): [0.37932273134655203, 0.3566751534600455, 0.24959305151949862, 0.5717405964378164, 0.23642854299083843]
# average success probability: 0.3587520151509502
# success probabilities (state-by-state): [0.28237743267414717, 0.4042906333101823, 0.4439851768398482, 0.41162869155108955, 0.5363105604893919]
# average success probability: 0.4157184989729318
# success probabilities (state-by-state): [0.23246002263194068, 0.6924903179425457, 0.30508800806638536, 0.2720953854249364, 0.3871065678902563]
# average success probability: 0.3778480603912129
# success probabilities (state-by-state): [0.4067921582658147, 0.29391113515127315, 0.4691679286519803, 0.2641533795482663, 0.08521165104395771]
# average success probability: 0.3038472505322584
# success probabilities (state-by-state): [0.3756058444200792, 0.3219520375439317, 0.566939277392363, 0.5913800518494949, 0.29501998950917596]
# average success probability: 0.4301794401430089

# %% [markdown]
# # From config_mkp_2d

# %%
omega_1 = (1.0,
            0.35353906418624204) # (r, phi)

omega_2 = (1.0,
            2.6888336243467514)

omega_3 = (1.0,
            -1.238332154160901)

omega_4 = (1.0,
            2.2568269306068403)

omega_5 = (1.0,
            1.096980655833204)

omega_6 = (-1.0,
            0.7433378263106715)

listOfOmegas = [omega_1, omega_2, omega_3, omega_4, omega_5, omega_6]
listOfPhases = [0.35353906418624204, 2.6888336243467514, -1.238332154160901, 2.2568269306068403, 1.096980655833204, 0.7433378263106715]

# %% [markdown]
# # From mkp_2d_2 (in drive, most recent run of pytheus)

# %%
omega_1 = (-1.0,
            -1.1814420501311425) # a_0 -> d_0 (p1)

omega_2 = (-1.0,
            1.307406489445125) # b_1 -> c_0 (p2)

omega_3 = (1.0,
            -0.36084763377486) # b_1 -> d_0 (p3)

omega_4 = (-1.0,
            -0.8278879640627096) # a_1 -> d_0 (p4)

omega_5 = (1.0,
            0.8391749136099179) # a_1 -> c_0 (p5)

omega_6 = (1.0,
            -0.006752021840030718) # b_0 -> d_0 (p6)

listOfPhases = [omega_1[1], omega_2[1], omega_3[1], omega_4[1], omega_5[1], omega_6[1]]

# Convert phases from -pi to pi to 0 to 2pi

for i in range(len(listOfPhases)):
    if listOfPhases[i]<0:
        listOfPhases[i] += 2*np.pi
        
# For phases with negative radius: add pi phase 

negRadius = [np.pi, np.pi, 0, np.pi, 0, 0]

updatePhase = [sum(x)%(2*np.pi) for x in zip(listOfPhases, negRadius)]

print(listOfPhases)
print(updatePhase)

# %% [markdown]
# post processing

# %%
# Introduce additional phases due to reflecting elements

reflectingPhases = [3*np.pi/2, np.pi, 0, np.pi, 0, np.pi]

# SUBTRACT the phases together (modulo 2*pi)

finalPhases = [(a-b)%(2*np.pi) for a,b in zip(updatePhase, reflectingPhases)]

print(finalPhases)

# %% [markdown]
# now compute the probability amplitude

# %%
vaaFun = 'expansionFuncs/2D_MKP_VAA_SingleProject.txt'


randomPhases = [np.random.uniform(0,np.pi) for i in range(6)]
probAmps = computeProb(randomPhases, vaaFun, 2) 
print(probAmps)
